# %%
import random

question_count = 0
correct = 0
incorrect = 0
game_continue = True
question_collection = []

ques_1 = ['The logical level model includes: \n'
          '> Purpose\n'
          '> Identity\n'
          '> Values and Beliefs\n'
          '> Skills and Capabilities\n'
          '> Behaviors\n'
          '> __________',
          'Enviroment',
          'Strength',
          'Vision',
          'Emotion']
ques_2 = ['The logical level model includes: \n'
          '> Purpose\n'
          '> Identity\n'
          '> Values and Beliefs\n'
          '> Skills and Capabilities\n'
          '> __________\n'
          '> Enviroment',
          'Behaviors',
          'Strength',
          'Characteristics',
          'Knowledge']
ques_3 = ['The logical level model includes: \n'
          '> Purpose\n'
          '> Identity\n'
          '> Values and Beliefs\n'
          '> __________\n'
          '> Behaviors\n'
          '> Enviroment',
          'Skills and Capabilities',
          'Emotion and Intellegences',
          'Vision and Mission',
          'Inspiration']
ques_4 = ['The logical level model includes: \n'
          '> Purpose\n'
          '> Identity\n'
          '> __________\n'
          '> Skills and Capabilities\n'
          '> Behaviors\n'
          '> Enviroment',
          'Values and Beliefs',
          'Knowledge',
          'Vision and Mission',
          'Inspiration']
ques_5 = ['The logical level model includes: \n'
          '> Purpose\n'
          '> __________\n'
          '> Values and Beliefs\n'
          '> Skills and Capabilities\n'
          '> Behaviors\n'
          '> Enviroment',
          'Identity',
          'Knowledge',
          'Vision and Mission',
          'Inspiration']
ques_6 = ['The logical level model includes: \n'
          '> __________\n'
          '> Identity\n'
          '> Values and Beliefs\n'
          '> Skills and Capabilities\n'
          '> Behaviors\n'
          '> Enviroment',
          'Purpose',
          'Emotion and Intellegences',
          'Vision and Mission',
          'Inspiration']
ques_7 = ['The spoken vs. lived values are: \n'
          '> Be mindful of the gap between what is promoted and reality\n'
          '> Values are developed and spoken, but not lived\n'
          '> __________',
          'We claim to value teamwork and talk about it all the time, but the artefacts\n'
          'are entirely individualistic',
          'Quality and strength of the collaborative relationship',
          'Feel the meaning behind their actions',
          'Expression of enthusiasm as though each team is unique… not routine']
ques_8 = ['The spoken vs. lived values are: \n'
          '> Be mindful of the gap between what is promoted and reality\n'
          '> __________\n'
          '> We claim to value teamwork and talk about it all the time, but the artefacts\n'
          'are entirely individualistic',
          'Values are developed and spoken, but not lived',
          'Quality and strength of the collaborative relationship',
          'Feel the meaning behind their actions',
          'Expression of enthusiasm as though each team is unique… not routine']
ques_9 = ['The spoken vs. lived values are: \n'
          '> __________\n'
          '> Values are developed and spoken, but not lived\n'
          '> We claim to value teamwork and talk about it all the time, but the artefacts\n'
          'are entirely individualistic',
          'Be mindful of the gap between what is promoted and reality',
          'Quality and strength of the collaborative relationship',
          'Feel the meaning behind their actions',
          'Expression of enthusiasm as though each team is unique… not routine']
ques_10 = ['Tacit Assumptions (Shein, 2013) is __________.',
          'Values are developed and spoken, but not lived',
          'Be mindful of the gap between what is promoted and reality',
          'Quality and strength of the collaborative relationship',
          'We claim to value teamwork and talk about it all the time, but the artefacts\n'
           'are entirely individualistic']
ques_11 = ['We claim to value teamwork and talk about it all the time, but the artefacts – our\n'
          'promotional systems and reward systems – are entirely individualistic are deifned by:',
          'Shein, 2013',
          'Katzenbach and Smith, 1993',
          'Deci and Ryan, 1985',
          'Price and Toye, 2017']
ques_12 = ['Hawkins and Smith (2013) Four Levels of Engagement Model include:\n'
           '> Level 1: Data and narrative\n'
           '> Level 2: Patterns and behavior\n'
           '> Level 3: Emotional patterns and triggers\n'
           '> Level 4: ___________',
           'Mindset, assumptions, beliefs – the stories we live within',
           'Values are developed and spoken, but not lived',
           'Be mindful of the gap between what is promoted and reality',
           'Quality and strength of the collaborative relationship']
ques_13 = ['Hawkins and Smith (2013) Four Levels of Engagement Model include:\n'
           '> Level 1: Data and narrative\n'
           '> Level 2: Patterns and behavior\n'
           '> Level 3: ___________\n'
           '> Level 4: Mindset, assumptions, beliefs – the stories we live within',
           'Emotional patterns and triggers',
           'Values are developed and spoken, but not lived',
           'Be mindful of the gap between what is promoted and reality',
           'Quality and strength of the collaborative relationship']
ques_14 = ['Hawkins and Smith (2013) Four Levels of Engagement Model include:\n'
           '> Level 1: Data and narrative\n'
           '> Level 2: ___________\n'
           '> Level 3: Emotional patterns and triggers\n'
           '> Level 4: Mindset, assumptions, beliefs – the stories we live within',
           'Patterns and behavior',
           'Values are developed and spoken, but not lived',
           'Be mindful of the gap between what is promoted and reality',
           'Quality and strength of the collaborative relationship']
ques_15 = ['Hawkins and Smith (2013) Four Levels of Engagement Model include:\n'
           '> Level 1: ___________\n'
           '> Level 2: Patterns and behavior\n'
           '> Level 3: Emotional patterns and triggers\n'
           '> Level 4: Mindset, assumptions, beliefs – the stories we live within',
           'Data and narrative',
           'Values are developed and spoken, but not lived',
           'Be mindful of the gap between what is promoted and reality',
           'Quality and strength of the collaborative relationship']
ques_16 = ["""Kantor(2012) Four Actions Stances
                                    ____________
                                   |___Follow___|
                                          |             
                    ___________           |Support      ____________
                   |___Move____|Initiate__|____________|___Oppose___|
                                          |  Challenge 
                                   Reflect|
                                    ______|______
                                   |_____???_____|
                                  
""",
           'Bystand',
           'Inspire',
           'Engage',
           'Courage']
ques_17 = ["""Kantor(2012) Four Actions Stances
                                    ____________
                                   |___Follow___|
                                          |             
                    ___________           |Support      ____________
                   |___Move____|Initiate__|____________|___Oppose___|
                                          |  Challenge 
                                      ??? |
                                    ______|______
                                   |___Bystand___|
                                  
""",
           'Reflect',
           'Inspire',
           'Engage',
           'Courage']
ques_18 = ["""Kantor(2012) Four Actions Stances
                                    ____________
                                   |___Follow___|
                                          |             
                    ___________           |Support      ____________
                   |___Move____|Initiate__|____________|___Oppose___|
                                          |        ??? 
                                  Reflect |
                                    ______|______
                                   |___Bystand___|
                                  
""",
           'Challenge',
           'Empathy',
           'Confidence',
           'Discourage']
ques_19 = ["""Kantor(2012) Four Actions Stances
                                    ____________
                                   |___Follow___|
                                          |             
                    ___________           |Support      ____________
                   |___Move____|Initiate__|____________|_____???____|
                                          |   Challenge       
                                  Reflect |
                                    ______|______
                                   |___Bystand___|
                                  
""",
           'Oppose',
           'Empathy',
           'Confidence',
           'Discourage']
ques_20 = ["""Kantor(2012) Four Actions Stances
                                    ____________
                                   |___Follow___|
                                          |             
                    ___________           |???          ____________
                   |___Move____|Initiate__|____________|___Oppose___|
                                          |   Challenge       
                                  Reflect |
                                    ______|______
                                   |___Bystand___|
                                  
""",
           'Support',
           'Empathy',
           'Confidence',
           'Discourage']
ques_21 = ["""Kantor(2012) Four Actions Stances
                                    ____________
                                   |_____???____|
                                          |             
                    ___________           |Support      ____________
                   |___Move____|Initiate__|____________|___Oppose___|
                                          |   Challenge       
                                  Reflect |
                                    ______|______
                                   |___Bystand___|
                                  
""",
           'Follow',
           'Lead',
           'Encourage',
           'Develop']

ques_22 = ["""Kantor(2012) Four Actions Stances
                                    ____________
                                   |___Follow___|
                                          |             
                    ___________           |Support      ____________
                   |___Move____|???_______|____________|___Oppose___|
                                          |   Challenge       
                                  Reflect |
                                    ______|______
                                   |___Bystand___|
                                  
""",
           'Initiate',
           'Lead',
           'Encourage',
           'Develop']
ques_23 = ["""Kantor(2012) Four Actions Stances
                                    ____________
                                   |___Follow___|
                                          |             
                    ___________           |Support      ____________
                   |____???____|Initiate__|____________|___Oppose___|
                                          |   Challenge       
                                  Reflect |
                                    ______|______
                                   |___Bystand___|
                                  
""",
           'Move',
           'Lead',
           'Encourage',
           'Develop']
ques_24 = ['Kantor(2012) Four Actions Stances include:\n'
           '> Level 1: The four action stances - Move, Follow, Bystand, Oppose\n'
           '> Level 2: Domains of communication - Affect, Power, Means\n'
           '> Level 3: Systems in control of speech - Open, Closed, Random\n'
           '> Level 4: __________',
           'Identity and personal stories',
           'Mission and Vision',
           'In-group and Out-group',
           'Collaboration']
ques_25 = ['Kantor(2012) Four Actions Stances include:\n'
           '> Level 1: The four action stances - Move, Follow, Bystand, Oppose\n'
           '> Level 2: Domains of communication - Affect, Power, Means\n'
           '> Level 3: Systems in control of speech - __________\n'
           '> Level 4: Identity and personal stories',
           'Open, Closed, Random',
           'Enviroment',
           'Confidence',
           'Collaboration']
ques_26 = ['Kantor(2012) Four Actions Stances include:\n'
           '> Level 1: The four action stances - Move, Follow, Bystand, Oppose\n'
           '> Level 2: Domains of communication - __________\n'
           '> Level 3: Systems in control of speech - Open, Closed, Random\n'
           '> Level 4: Identity and personal stories',
           'Affect, Power, Means',
           'Enviroment',
           'Mission',
           'Collaboration']
ques_27 = ['Kantor(2012) Four Actions Stances include:\n'
           '> Level 1: The four action stances - ___________\n'
           '> Level 2: Domains of communication - Affect, Power, Means\n'
           '> Level 3: Systems in control of speech - Open, Closed, Random\n'
           '> Level 4: Identity and personal stories',
           'Move, Follow, Bystand, Oppose',
           'Initiate, Disucss, Implement, Review',
           'Motivate, Action, Result, Review',
           'Visial, Design, Implement, Redesign']
ques_28 = ["""Key elements of developing team awareness are:
                                    ________________________________
                                   /                |               \\
                                  / Team coach      |Team awareness  \\
                                 /  awareness       |of group dynamics\\
                                |           ________|________          |
                                |          |                 |_________|
                                |__________| Team awareness  |         |
                                |          |_________________|         |
                                |  Team individual  |                  |
                                \\  and collective   |      ???         /
                                 \\  self awareness  |                 /
                                  \\_________________|________________/
""",
           'Team systemic awareness',
           'Team skills and capabilities',
           'Team values and beliefs',
           'Team collaboration']
ques_29 = ["""Key elements of developing team awareness are:
                                    ________________________________
                                   /                |               \\
                                  / Team coach      |Team awareness  \\
                                 /  awareness       |of group dynamics\\
                                |           ________|________          |
                                |          |                 |_________|
                                |__________| Team awareness  |         |
                                |          |_________________|         |
                                |                   |                  |
                                \\        ???        | Team systemic    /
                                 \\                  | awareness       /
                                  \\_________________|________________/
""",
           'Team individual and collective self awareness',
           'Team skills and capabilities',
           'Team values and beliefs',
           'Team collaboration']
ques_30 = ["""Key elements of developing team awareness are:
                                    ________________________________
                                   /                |               \\
                                  /                 |Team awareness  \\
                                 /       ???        |of group dynamics\\
                                |           ________|________          |
                                |          |                 |_________|
                                |__________| Team awareness  |         |
                                |          |_________________|         |
                                |  Team individual  |                  |
                                \\  and collective   | Team systemic    /
                                 \\  self awareness  | awareness       /
                                  \\_________________|________________/
""",
           'Team coach awareness',
           'Team skills and capabilities',
           'Team values and beliefs',
           'Team collaboration']
ques_31 = ["""Key elements of developing team awareness are:
                                    ________________________________
                                   /                |               \\
                                  / Team coach      |                \\
                                 /  awareness       |      ???        \\
                                |           ________|________          |
                                |          |                 |_________|
                                |__________| Team awareness  |         |
                                |          |_________________|         |
                                |  Team individual  |                  |
                                \\  and collective   | Team systemic    /
                                 \\  self awareness  | awareness       /
                                  \\_________________|________________/
""",
           'Team awareness of group dynamics',
           'Team skills and capabilities',
           'Team values and beliefs',
           'Team collaboration']
ques_32 = ["""Personal identity wheel is consist of following components:
                                   
                                             Who are
                                            my family?
                                What are         |       Where did I       
                                my goals?        |        grow up?
                                         \\       |      /
                                          \\______|_____/
                         What am I        |            |      What are my hobbies
                       most proud of? <---|   My name  |--->    and interest?
                                          |____________|       
                                         /       |      \\
                                What is /        |       \\
                               important         |       ???
                                 to me?     What is my
                                             greatest 
                                             strength?
                
""",
           'What is my work history?',
           'What is my purpose?',
           'What is my weakness?',
           'What do I value most?']
ques_33 = ["""Personal identity wheel is consist of following components:
                                   
                                             Who are
                                            my family?
                                What are         |       Where did I      
                                my goals?        |        grow up?
                                         \\       |      /
                                          \\______|_____/
                         What am I        |            |      What are my hobbies
                       most proud of? <---|   My name  |--->    and interest?
                                          |____________|       
                                         /       |      \\
                                What is /        |       \\
                               important         |       What is
                                 to me?         ???        work
                                                         history?

                
""",
           'What is my greatest strength?',
           'What is my purpose?',
           'What is my weakness?',
           'What do I value most?']
ques_34 = ["""Personal identity wheel is consist of following components:
                                   
                                             Who are
                                            my family?
                                What are         |       Where did I       
                                my goals?        |        grow up?
                                         \\       |      /
                                          \\______|_____/
                         What am I        |            |      What are my hobbies
                       most proud of? <---|   My name  |--->    and interest?
                                          |____________|       
                                         /       |      \\
                                        /        |       \\
                                      ???        |       What is
                                              What is      work
                                            my greatest   history?
                                             strength?
                
""",
           'What is important to me?',
           'What is my purpose?',
           'What is my weakness?',
           'What do I value most?']
ques_35 = ["""Personal identity wheel is consist of following components:
                                   
                                             Who are
                                            my family?
                                What are         |       Where did I      
                                my goals?        |        grow up?
                                         \\       |      /
                                          \\______|_____/
                                          |            |      What are my hobbies
                                  ??? <---|   My name  |--->    and interest?
                                          |____________|       
                                         /       |      \\
                                        /        |       \\
                                  What is        |       What is
                                 important     What is      work
                                  to me?    my greatest   history?
                                             strength?
                
""",
           'What am I proud of?',
           'What is my purpose?',
           'What is my weakness?',
           'What do I value most?']
ques_36 = ["""Personal identity wheel is consist of following components:
                                   
                                             Who are
                                            my family?
                                                 |       Where did I      
                                      ???        |        grow up?
                                         \\       |      /
                                          \\______|_____/
                            What am I     |            |      What are my hobbies
                            proud of? <---|   My name  |--->    and interest?
                                          |____________|       
                                         /       |      \\
                                        /        |       \\
                                  What is        |       What is
                                 important     What is      work
                                  to me?    my greatest   history?
                                             strength?
                
""",
           'What are my goals?',
           'What is my purpose?',
           'What is my weakness?',
           'What do I value most?']
ques_37 = ["""Personal identity wheel is consist of following components:
                                   
                                             
                                                 ???
                                 What are        |       Where did I      
                                 my goals?       |        grow up?
                                         \\       |      /
                                          \\______|_____/
                            What am I     |            |      What are my hobbies
                            proud of? <---|   My name  |--->    and interest?
                                          |____________|       
                                         /       |      \\
                                        /        |       \\
                                  What is        |       What is
                                 important     What is      work
                                  to me?    my greatest   history?
                                             strength?
                
""",
           'Who are my family?',
           'What is my purpose?',
           'What is my weakness?',
           'What do I value most?']
ques_38 = ["""Personal identity wheel is consist of following components:
                                   
                                               Who are
                                              my family?   
                                 What are        |              
                                 my goals?       |      ???
                                         \\       |      /
                                          \\______|_____/
                            What am I     |            |      What are my hobbies
                            proud of? <---|   My name  |--->    and interest?
                                          |____________|       
                                         /       |      \\
                                        /        |       \\
                                  What is        |       What is
                                 important     What is      work
                                  to me?    my greatest   history?
                                             strength?
                
""",
           'Where did I grow up?',
           'What is my purpose?',
           'What is my weakness?',
           'What do I value most?']
ques_39 = ["""Personal identity wheel is consist of following components:
                                   
                                               Who are
                                              my family?   
                                 What are        |      Where did I        
                                 my goals?       |       grow up?
                                         \\       |      /
                                          \\______|_____/
                            What am I     |            |      
                            proud of? <---|   My name  |---> ???
                                          |____________|       
                                         /       |      \\
                                        /        |       \\
                                  What is        |       What is
                                 important     What is      work
                                  to me?    my greatest   history?
                                             strength?
                
""",
           'What are my hobbies and interest?',
           'What is my purpose?',
           'What is my weakness?',
           'What do I value most?']
ques_40 = ["""Logical model pyramid is made of:
                                   
                                            /\\
                                           /  \\
                                          /    \\
                                         /      \\
                                        /        \\
                                       /Enviroment\\
                                      /------------\\
                                     /  Bahaviours  \\
                                    /----------------\\
                                   /Skills&Capabiliti.\\
                                  /--------------------\\
                                 /   Values & Beliefs   \\
                                /------------------------\\ 
                               /         Identity         \\
                              /----------------------------\\
                             /              ???             \\
                            /________________________________\\
""", 
           'Purpose',
           'Strength',
           'Mission',
           'Vision']
ques_41 = ["""Logical model pyramid is made of:
                                   
                                            /\\
                                           /  \\
                                          /    \\
                                         /      \\
                                        /        \\
                                       /Enviroment\\
                                      /------------\\
                                     /  Bahaviours  \\
                                    /----------------\\
                                   /Skills&Capabiliti.\\
                                  /--------------------\\
                                 /   Values & Beliefs   \\
                                /------------------------\\ 
                               /            ???           \\
                              /----------------------------\\
                             /            Purpose           \\
                            /________________________________\\
""", 
           'Identity',
           'Inspiration',
           'Challenge',
           'Vision']
ques_42 = ["""Logical model pyramid is made of:
                                   
                                            /\\
                                           /  \\
                                          /    \\
                                         /      \\
                                        /        \\
                                       /Enviroment\\
                                      /------------\\
                                     /  Bahaviours  \\
                                    /----------------\\
                                   /Skills&Capabiliti.\\
                                  /--------------------\\
                                 /          ???         \\
                                /------------------------\\ 
                               /         Identity         \\
                              /----------------------------\\
                             /            Purpose           \\
                            /________________________________\\
""", 
           'Values & Beliefs',
           'Inspiration',
           'Challenge',
           'Vision']
ques_43 = ["""Logical model pyramid is made of:
                                   
                                            /\\
                                           /  \\
                                          /    \\
                                         /      \\
                                        /        \\
                                       /Enviroment\\
                                      /------------\\
                                     /  Bahaviours  \\
                                    /----------------\\
                                   /       ???        \\
                                  /--------------------\\
                                 /   Values & Beliefs   \\
                                /------------------------\\ 
                               /         Identity         \\
                              /----------------------------\\
                             /            Purpose           \\
                            /________________________________\\
""", 
           'Skills and Capabilities',
           'Inspiration',
           'Challenge',
           'Vision']
ques_44 = ["""Logical model pyramid is made of:
                                   
                                            /\\
                                           /  \\
                                          /    \\
                                         /      \\
                                        /        \\
                                       /Enviroment\\
                                      /------------\\
                                     /      ???     \\
                                    /----------------\\
                                   /Skills&Capabiliti.\\
                                  /--------------------\\
                                 /   Values & Beliefs   \\
                                /------------------------\\ 
                               /         Identity         \\
                              /----------------------------\\
                             /            Purpose           \\
                            /________________________________\\
""", 
           'Bahaviours',
           'Execution',
           'Challenge',
           'Action']
ques_45 = ["""Logical model pyramid is made of:
                                   
                                            /\\
                                           /  \\
                                          /    \\
                                         /      \\
                                        /        \\
                                       /   ???    \\
                                      /------------\\
                                     /  Behaviours  \\
                                    /----------------\\
                                   /Skills&Capabiliti.\\
                                  /--------------------\\
                                 /   Values & Beliefs   \\
                                /------------------------\\ 
                               /         Identity         \\
                              /----------------------------\\
                             /            Purpose           \\
                            /________________________________\\
""", 
           'Enviroment',
           'Execution',
           'Challenge',
           'Action']
ques_46 = ["Components of aligning your own team's interests are: \n"
           '> Plot out conflicts\n'
           '> Work with constituents\n'
           '> Mediate conflicts of interest\n'
           '> __________',
           'Persuade with data',
           'Implement new policy',
           'Negotiate internally',
           'Compromise individual benefits']
ques_47 = ["Components of aligning your own team's interests are: \n"
           '> Plot out conflicts\n'
           '> Work with constituents\n'
           '> __________\n'
           '> Persuade with data',
           'Mediate conflicts of interest',
           'Implement new policy',
           'Negotiate internally',
           'Compromise individual benefits']
ques_48 = ["Components of aligning your own team's interests are: \n"
           '> Plot out conflicts\n'
           '> __________\n'
           '> Mediate conflicts of interest\n'
           '> Persuade with data',
           'Work with constituents',
           'Implement new policy',
           'Negotiate internally',
           'Compromise individual benefits']
ques_49 = ["Components of aligning your own team's interests are: \n"
           '> __________\n'
           '> Work with constituents\n'
           '> Mediate conflicts of interest\n'
           '> Persuade with data',
           'Plot out conflicts',
           'Implement new policy',
           'Negotiate internally',
           'Compromise individual benefits']
ques_50 = ["Components of implementinga a shared strategy include: \n"
           '> __________\n'
           '> Work with constituents\n'
           '> Mediate conflicts of interest\n'
           '> Persuade with data',
           'Simulate the negotiation',
           'Plot out conflicts',
           'Work with constituents',
           'Mediate conflicts of interest']
ques_51 = ["Components of implementinga a shared strategy include: \n"
           '> __________\n'
           "> Assign roles to capitalize on team members' strengths and interests\n"
           '> Establish a plan for intrateam communication',
           'Simulate the negotiation',
           'Plot out conflicts',
           'Work with constituents',
           'Mediate conflicts of interest']
ques_52 = ["Components of implementinga a shared strategy include: \n"
           '> Simulate the negotiation\n'
           "> __________\n"
           '> Establish a plan for intrateam communication',
           "Assign roles to capitalize on team members' strengths and interests",
           'Expression enthusiasm of each team members',
           'Initiate collaboration roles',
           'Develop team members collaboration']
ques_53 = ["Components of implementinga a shared strategy include: \n"
           '> Simulate the negotiation\n'
           "> Assign roles to capitalize on team members' strengths and interests\n"
           '> __________',
           "Establish a plan for intrateam communication",
           'Expression enthusiasm of each team members',
           'Initiate collaboration system',
           'Develop team members collaboration']
ques_54 = ["Four steps to focus on 'lowercase n' negotiations: \n"
           '> 1. Recognize\n'
           "> 2. Prepare\n"
           '> 3. Initiate\n'
           '> 4. __________',
           "Navigate",
           'Develop',
           'Mitigate',
           'Execute']
ques_55 = ["Four steps to focus on 'lowercase n' negotiations: \n"
           '> 1. Recognize\n'
           "> 2. Prepare\n"
           '> 3. __________\n'
           '> 4. Navigate',
           "Initiate",
           'Develop',
           'Mitigate',
           'Execute']
ques_56 = ["Four steps to focus on 'lowercase n' negotiations: \n"
           '> 1. Recognize\n'
           "> 2. __________\n"
           '> 3. Initiate\n'
           '> 4. Navigate',
           "Prepare",
           'Develop',
           'Mitigate',
           'Execute']
ques_57 = ["Four steps to focus on 'lowercase n' negotiations: \n"
           '> 1. __________\n'
           "> 2. Prepare\n"
           '> 3. Initiate\n'
           '> 4. Navigate',
           "Recognize",
           'Develop',
           'Mitigate',
           'Execute']
ques_58 = ["How to preapre for informal negotiation?\n"
           '> 1. Gather good information\n'
           "> 2. Position yourself\n"
           '> 3. __________',
           "Anchor with options",
           'Bargain best position',
           'Offer best options',
           'Executive your decision']
ques_59 = ["How to preapre for informal negotiation?\n"
           '> 1. Gather good information\n'
           "> 2. __________\n"
           '> 3. Anchor with options',
           "Position yourself",
           'Bargain best position',
           'Offer best options',
           'Executive your decision']
ques_60 = ["How to preapre for informal negotiation?\n"
           '> 1. __________\n'
           "> 2. Position yourself\n"
           '> 3. Anchor with options',
           "Gather good information",
           'Prepare best offer',
           'Initiate good idea',
           'Look for more options']
ques_61 = ["CEO blames the executives for indicisiveness and executives\n"
           "resent CEO for acting like a dicitator. This is called?",
           "Dictator-by-default syndrome",
           'Tatic assumption',
           'Emotional patterns and triggers',
           'Unhelpful group dynamics']
ques_62 = ["What are the pratical measures to break the impasse?\n"
           "1. Asking the impossible\n"
           '2. Acknowledging the problem\n'
           '3. __________',
           'Managing the impossible',
           'Gather good information',
           'Simulate the negotiation',
           'Work with constituents']
ques_63 = ["What are the pratical measures to break the impasse?\n"
           "1. Asking the impossible\n"
           '2. __________\n'
           '3. Managing the impossible',
           'Acknowledging the problem',
           'Gather good information',
           'Simulate the negotiation',
           'Work with constituents']
ques_64 = ["What are the pratical measures to break the impasse?\n"
           "1. __________\n"
           '2. Acknowledging the problem\n'
           '3. Managing the impossible',
           'Asking the impossible',
           'Gather good information',
           'Simulate the negotiation',
           'Work with constituents']
ques_65 = ["What are the tactics to minimize potential dysfunction\n"
           "when making team decision?\n"
           "1. __________\n"
           '2. Provide a range of options for achieving outcomes\n'
           '3. Test fences and walls\n'
           '4. Surface preferences early\n'
           '5. State each option’s pros and cons\n'
           '6. Devise new options that preserve the best features of existing ones',
           'Articulate clearly what outcome you are seeking',
           'Gather good information',
           'Simulate the negotiation',
           'Acknowledging the problem']
ques_66 = ["What are the tactics to minimize potential dysfunction\n"
           "when making team decision?\n"
           "1. Articulate clearly what outcome you are seeking\n"
           '2. __________\n'
           '3. Test fences and walls\n'
           '4. Surface preferences early\n'
           '5. State each option’s pros and cons\n'
           '6. Devise new options that preserve the best features of existing ones',
           'Provide a range of options for achieving outcomes',
           'Gather good information',
           'Anchor with options',
           'Acknowledging the problem']
ques_67 = ["What are the tactics to minimize potential dysfunction\n"
           "when making team decision?\n"
           "1. Articulate clearly what outcome you are seeking\n"
           '2. Provide a range of options for achieving outcomes\n'
           '3. __________\n'
           '4. Surface preferences early\n'
           '5. State each option’s pros and cons\n'
           '6. Devise new options that preserve the best features of existing ones',
           'Test fences and walls',
           'Gather good information',
           'Simulate the negotiation',
           'Acknowledging the problem']
ques_68 = ["What are the tactics to minimize potential dysfunction\n"
           "when making team decision?\n"
           "1. Articulate clearly what outcome you are seeking\n"
           '2. Provide a range of options for achieving outcomes\n'
           '3. Test fences and walls\n'
           '4. __________\n'
           '5. State each option’s pros and cons\n'
           '6. Devise new options that preserve the best features of existing ones',
           'Surface preferences early',
           'Gather good information',
           'Simulate the negotiation',
           'Acknowledging the problem']
ques_69 = ["What are the tactics to minimize potential dysfunction\n"
           "when making team decision?\n"
           "1. Articulate clearly what outcome you are seeking\n"
           '2. Provide a range of options for achieving outcomes\n'
           '3. Test fences and walls\n'
           '4. Surface preferences early\n'
           '5. __________\n'
           '6. Devise new options that preserve the best features of existing ones',
           'State each option’s pros and cons',
           "Assign roles to capitalize on team members' strengths and interests",
           'Establish a plan for intrateam communication',
           'Acknowledging the problem']
ques_70 = ["What are the tactics to minimize potential dysfunction\n"
           "when making team decision?\n"
           "1. Articulate clearly what outcome you are seeking\n"
           '2. Provide a range of options for achieving outcomes\n'
           '3. Test fences and walls\n'
           '4. Surface preferences early\n'
           '5. State each option’s pros and cons\n'
           '6. __________',
           'Devise new options that preserve the best features of existing ones',
           'Establish a plan for intrateam communication',
           'Simulate the negotiation',
           "Assign roles to capitalize on team members' strengths and interests"]
ques_71 = ["If the team thwart toward dictator-by-default syndrome. What two\n"
           "ground they must adhere?\n"
           "1. Deliberate confi dentially\n"
           '2. __________',
           'Deliberate over an appropriate time frame',
           'Provide a range of options for achieving outcomes',
           'State each option’s pros and cons',
           "Assign roles to capitalize on team members' strengths and interests"]
ques_72 = ["If the team thwart toward dictator-by-default syndrome. What two\n"
           "ground they must adhere?\n"
           "1. __________\n"
           '2. Deliberate over an appropriate time frame',
           'Deliberate confi dentially',
           'Provide a range of options for achieving outcomes',
           'State each option’s pros and cons',
           "Articulate clearly what outcome you are seeking"]
ques_73 = ["What is the enabling conditions 4-D teams mean?\n"
           "ground they must adhere?\n"
           "1. Diverse\n"
           '2. Dispersed\n'
           '3. Digital\n'
           '4. __________',
           'Dynamic',
           'Deliberate',
           'Developed',
           "Domain"]
ques_74 = ["What is the enabling conditions 4-D teams mean?\n"
           "ground they must adhere?\n"
           "1. Diverse\n"
           '2. Dispersed\n'
           '3. __________\n'
           '4. Dynamic',
           'Digital',
           'Deliberate',
           'Developed',
           "Domain"]
ques_75 = ["What is the enabling conditions 4-D teams mean?\n"
           "ground they must adhere?\n"
           "1. Diverse\n"
           '2. __________\n'
           '3. Digital\n'
           '4. Dynamic',
           'Dispersed',
           'Deliberate',
           'Developed',
           "Domain"]
ques_76 = ["What is the enabling conditions 4-D teams mean?\n"
           "ground they must adhere?\n"
           "1. __________\n"
           '2. Dispersed\n'
           '3. Digital\n'
           '4. Dynamic',
           'Diverse',
           'Deliberate',
           'Developed',
           "Domain"]
ques_77 = ["What is the enabling conditions 4-D teams mean?\n"
           "ground they must adhere?\n"
           "1. __________\n"
           '2. Dispersed\n'
           '3. Digital\n'
           '4. Dynamic',
           'Diverse',
           'Deliberate',
           'Developed',
           "Domain"]
ques_78 = ["What are the 4 enable conditions?\n"
           "1. __________\n"
           '2. Strong structure\n'
           '3. Supportive context\n'
           '4. Shared mindset',
           'Compelling direction',
           'Acknowledging the problem',
           'Work with constituents',
           "Persuade with data"]
ques_79 = ["What are the 4 enable conditions?\n"
           "1. Compelling direction\n"
           '2. __________\n'
           '3. Supportive context\n'
           '4. Shared mindset',
           'Strong structure',
           'Simulate the negotiation',
           'Work with constituents',
           "Persuade with data"]
ques_80 = ["What are the 4 enable conditions?\n"
           "1. Compelling direction\n"
           '2. Strong structure\n'
           '3. __________\n'
           '4. Shared mindset',
           'Supportive context',
           'Acknowledging the problem',
           'Simulate the negotiation',
           "Persuade with data"]
ques_81 = ["What are the 4 enable conditions?\n"
           "1. Compelling direction\n"
           '2. Strong structure\n'
           '3. Supportive context\n'
           '4. __________',
           'Shared mindset',
           'Acknowledging the problem',
           'Work with constituents',
           "Persuade with data"]
ques_82 = ["To evaluate 4 enable condition effectively, what 3 criteria are required?\n"
           "1. Output\n"
           '2. Collaborative ability\n'
           '3. __________',
           'Individual development',
           'Gather good information',
           'Supprotive mindset',
           "Ask for impossible"]
ques_83 = ["To evaluate 4 enable condition effectively, what 3 criteria are required?\n"
           "1. Output\n"
           '2. __________\n'
           '3. Individual development',
           'Collaborative ability',
           'Team collaboration',
           'Supprotive mindset',
           "Team coaching"]
ques_84 = ["To evaluate 4 enable condition effectively, what 3 criteria are required?\n"
           "1. __________\n"
           '2. Collaborative ability\n'
           '3. Individual development',
           'Output',
           'Purpose',
           'Negotiation',
           "Inspiration"]
ques_85 = ["What are three Hackman’s (1970) team enabling conditions?\n"
           "1. __________\n"
           '2. Strong structure\n'
           '3. Supportive context',
           'Compelling direction',
           'Purpose',
           'Shared mindset',
           "Identity"]
ques_86 = ["What are three Hackman’s (1970) team enabling conditions?\n"
           "1. Compelling direction\n"
           '2. __________\n'
           '3. Supportive context',
           'Strong structure',
           'Team building',
           'Shared mindset',
           "Identity"]
ques_87 = ["What are three Hackman’s (1970) team enabling conditions?\n"
           "1. Compelling direction\n"
           '2. Strong structure\n'
           '3. __________',
           'Supportive context',
           'Team building',
           'Shared mindset',
           "Purpose"]

    
# manual add questions into question bank
question_collection = [ques_1, ques_2, ques_3, ques_4, ques_5, ques_6, ques_7, ques_8, ques_9, ques_10, ques_11, ques_12,
                       ques_13, ques_14, ques_15, ques_16, ques_17, ques_18, ques_19, ques_20, ques_21, ques_22, ques_23,
                       ques_24, ques_25, ques_26, ques_27, ques_28, ques_29, ques_30, ques_31, ques_32, ques_33, ques_34, 
                       ques_35, ques_36, ques_37, ques_38, ques_39, ques_40, ques_41, ques_42, ques_43, ques_44, ques_45,
                       ques_46, ques_47, ques_48, ques_49, ques_50, ques_51, ques_52, ques_53, ques_54, ques_55, ques_56,
                       ques_57, ques_58, ques_59, ques_60, ques_61, ques_62, ques_63, ques_64, ques_65, ques_66, ques_67,
                       ques_68, ques_69, ques_70, ques_71, ques_72, ques_73, ques_74, ques_75, ques_76, ques_77, ques_78,
                       ques_79, ques_80, ques_81, ques_82, ques_83, ques_84, ques_85, ques_86, ques_87]
total_ques_size = len(question_collection)

while len(question_collection) != 0:
    question = random.choice(question_collection)
    question_count += 1
    shuffle_lst = question[1:]
    random.shuffle(shuffle_lst)
    correct_choice = 0
    print("\n", '-' * 50, 'NEXT', '-' * 50, '\n')
    print(f'{question_count}. {question[0]}\n')
    for ans in range(1,5):
        print(f"{ans}. ", shuffle_lst[ans - 1])
        if shuffle_lst[ans - 1] == question[1]:
            correct_choice = ans
    user_input = input('\n> ')
    user_input = int(user_input)
    
    
    try:
        
        if user_input == correct_choice:
            print("\n *** Correct! *** \n")
            correct += 1
            print(f"{len(question_collection) - 1} questions left.")
            print(f"Correct: {correct}")
            print(f"Wrong: {incorrect}")
            print(f"Total: {total_ques_size}")
            
        else:
            print(f'\n--- Incorrect!, the answer is >>> {question[1]} ---')
            incorrect += 1
            print(f"{len(question_collection) - 1} questions left.")
            print(f"Correct: {correct}")
            print(f"Wrong: {incorrect}")
            print(f"Total: {total_ques_size}")
    except:
        print("Some bug in the app!")
        
    question_collection.remove(question)

print(f"You have finished all the questions.\n Your score is {correct}/{question_count}")
# Out:
#  -------------------------------------------------- NEXT --------------------------------------------------
#
# 1. Components of aligning your own team's interests are:
# > Plot out conflicts
# > Work with constituents
# > Mediate conflicts of interest
# > __________
#
# 1.  Persuade with data
# 2.  Negotiate internally
# 3.  Compromise individual benefits
# 4.  Implement new policy
#
# > 1
#
#  *** Correct! ***
#
# 86 questions left.
# Correct: 1
# Wrong: 0
# Total: 87
#
#  -------------------------------------------------- NEXT --------------------------------------------------
#
# 2. Personal identity wheel is consist of following components:
#
#
#                                                  ???
#                                  What are        |       Where did I
#                                  my goals?       |        grow up?
#                                          \       |      /
#                                           \______|_____/
#                             What am I     |            |      What are my hobbies
#                             proud of? <---|   My name  |--->    and interest?
#                                           |____________|
#                                          /       |      \
#                                         /        |       \
#                                   What is        |       What is
#                                  important     What is      work
#                                   to me?    my greatest   history?
#                                              strength?
#
#
#
# 1.  What do I value most?
# 2.  Who are my family?
# 3.  What is my purpose?
# 4.  What is my weakness?
#
# > 2
#
#  *** Correct! ***
#
# 85 questions left.
# Correct: 2
# Wrong: 0
# Total: 87
#
#  -------------------------------------------------- NEXT --------------------------------------------------
#
# 3. Kantor(2012) Four Actions Stances include:
# > Level 1: The four action stances - Move, Follow, Bystand, Oppose
# > Level 2: Domains of communication - Affect, Power, Means
# > Level 3: Systems in control of speech - Open, Closed, Random
# > Level 4: __________
#
# 1.  Mission and Vision
# 2.  Identity and personal stories
# 3.  Collaboration
# 4.  In-group and Out-group
#
# > 2
#
#  *** Correct! ***
#
# 84 questions left.
# Correct: 3
# Wrong: 0
# Total: 87
#
#  -------------------------------------------------- NEXT --------------------------------------------------
#
# 4. Key elements of developing team awareness are:
#                                     ________________________________
#                                    /                |               \
#                                   /                 |Team awareness  \
#                                  /       ???        |of group dynamics\
#                                 |           ________|________          |
#                                 |          |                 |_________|
#                                 |__________| Team awareness  |         |
#                                 |          |_________________|         |
#                                 |  Team individual  |                  |
#                                 \  and collective   | Team systemic    /
#                                  \  self awareness  | awareness       /
#                                   \_________________|________________/
#
#
# 1.  Team skills and capabilities
# 2.  Team values and beliefs
# 3.  Team collaboration
# 4.  Team coach awareness
#
# > 4
#
#  *** Correct! ***
#
# 83 questions left.
# Correct: 4
# Wrong: 0
# Total: 87
#
#  -------------------------------------------------- NEXT --------------------------------------------------
#
# 5. How to preapre for informal negotiation?
# > 1. __________
# > 2. Position yourself
# > 3. Anchor with options
#
# 1.  Prepare best offer
# 2.  Initiate good idea
# 3.  Gather good information
# 4.  Look for more options
#
# > 3
#
#  *** Correct! ***
#
# 82 questions left.
# Correct: 5
# Wrong: 0
# Total: 87
#
#  -------------------------------------------------- NEXT --------------------------------------------------
#
# 6. Kantor(2012) Four Actions Stances
#                                     ____________
#                                    |___Follow___|
#                                           |
#                     ___________           |Support      ____________
#                    |___Move____|???_______|____________|___Oppose___|
#                                           |   Challenge
#                                   Reflect |
#                                     ______|______
#                                    |___Bystand___|
#
#
#
# 1.  Initiate
# 2.  Develop
# 3.  Lead
# 4.  Encourage
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [2], line 1121
#    1119     if shuffle_lst[ans - 1] == question[1]:
#    1120         correct_choice = ans
# -> 1121 user_input = input('\n> ')
#    1122 user_input = int(user_input)
#    1125 try:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ipykernel\kernelbase.py:1177, in Kernel.raw_input(self, prompt)
#    1173 if not self._allow_stdin:
#    1174     raise StdinNotImplementedError(
#    1175         "raw_input was called, but this frontend does not support input requests."
#    1176     )
# -> 1177 return self._input_request(
#    1178     str(prompt),
#    1179     self._parent_ident["shell"],
#    1180     self.get_parent("shell"),
#    1181     password=False,
#    1182 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ipykernel\kernelbase.py:1219, in Kernel._input_request(self, prompt, ident, parent, password)
#    1216             break
#    1217 except KeyboardInterrupt:
#    1218     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219     raise KeyboardInterrupt("Interrupted by user") from None
#    1220 except Exception:
#    1221     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
